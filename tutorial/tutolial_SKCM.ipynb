# %% [markdown]
# #Installation using pip command

# %%
# !pip install scsurv
# Out:
# Collecting scsurv
#   Downloading scsurv-0.2.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from scsurv) (2.8.0+cu126)
# Collecting lifelines>=0.27.8 (from scsurv)
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting scanpy>=1.9.5 (from scsurv)
#   Downloading scanpy-1.11.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from scsurv) (2.2.2)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from scsurv) (2.0.2)
# Requirement already satisfied: matplotlib>=3.7.2 in /usr/local/lib/python3.12/dist-packages (from scsurv) (3.10.0)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from scsurv) (1.16.2)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines>=0.27.8->scsurv) (1.8.0)
# Collecting autograd-gamma>=0.3 (from lifelines>=0.27.8->scsurv)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines>=0.27.8->scsurv)
#   Downloading formulaic-1.2.1-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.2->scsurv) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scsurv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scsurv) (2025.2)
# Collecting anndata>=0.8 (from scanpy>=1.9.5->scsurv)
#   Downloading anndata-0.12.2-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (3.14.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy>=1.9.5->scsurv)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (3.5)
# Requirement already satisfied: numba>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (0.60.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (1.6.1)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (0.13.2)
# Collecting session-info2 (from scanpy>=1.9.5->scsurv)
#   Downloading session_info2-0.2.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (0.14.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.5->scsurv) (0.5.9.post2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->scsurv) (3.4.0)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy>=1.9.5->scsurv)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy>=1.9.5->scsurv)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines>=0.27.8->scsurv)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines>=0.27.8->scsurv) (2.7.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines>=0.27.8->scsurv) (1.17.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.1->scanpy>=1.9.5->scsurv) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.2->scsurv) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.3->scanpy>=1.9.5->scsurv) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.1->scsurv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.1->scsurv) (3.0.3)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy>=1.9.5->scsurv)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy>=1.9.5->scsurv)
#   Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy>=1.9.5->scsurv) (6.0.3)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy>=1.9.5->scsurv)
#   Downloading crc32c-2.7.1.post0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Downloading scsurv-0.2.0-py3-none-any.whl (24.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 86.3 MB/s eta 0:00:00
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 39.6 MB/s eta 0:00:00
# Downloading scanpy-1.11.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 115.4 MB/s eta 0:00:00
# Downloading anndata-0.12.2-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 24.3 MB/s eta 0:00:00
# Downloading formulaic-1.2.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 16.1 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading session_info2-0.2.3-py3-none-any.whl (16 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 7.7 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 33.2 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 108.1 MB/s eta 0:00:00
# Downloading crc32c-2.7.1.post0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.8 MB/s eta 0:00:00
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=2853d309b3b2d71f277ad4fd0ac6b10cbc4d7b85460d5cc8b4e2ba181a8ae72d
#   Stored in directory: /root/.cache/pip/wheels/50/37/21/0a719b9d89c635e89ff24bd93b862882ad675279552013b2fb
# Successfully built autograd-gamma
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, interface-meta, donfig, crc32c, array-api-compat, autograd-gamma, zarr, formulaic, lifelines, anndata, scanpy, scsurv
# Successfully installed anndata-0.12.2 array-api-compat-1.12.0 autograd-gamma-0.5.0 crc32c-2.7.1.post0 donfig-0.8.1.post1 formulaic-1.2.1 interface-meta-1.3.0 legacy-api-wrap-1.4.1 lifelines-0.30.0 numcodecs-0.16.3 scanpy-1.11.4 scsurv-0.2.0 session-info2-0.2.3 zarr-3.1.3

# %% [markdown]
# #Download melanoma scRNA-seq dataset from GSE115978

# %%
# !wget https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115978/suppl/GSE115978%5Fcounts.csv.gz
# Out:
# --2025-10-14 11:20:32--  https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115978/suppl/GSE115978%5Fcounts.csv.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 130.14.250.31, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51508919 (49M) [application/x-gzip]
# Saving to: ‘GSE115978_counts.csv.gz’
#
# GSE115978_counts.cs 100%[===================>]  49.12M  13.7MB/s    in 4.6s
#
# 2025-10-14 11:20:38 (10.7 MB/s) - ‘GSE115978_counts.csv.gz’ saved [51508919/51508919]

# %%
# !wget https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115978/suppl/GSE115978%5Fcell.annotations.csv.gz
# Out:
# --2025-10-14 11:20:38--  https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115978/suppl/GSE115978%5Fcell.annotations.csv.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 130.14.250.31, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101286 (99K) [application/x-gzip]
# Saving to: ‘GSE115978_cell.annotations.csv.gz’
#
# GSE115978_cell.anno 100%[===================>]  98.91K   254KB/s    in 0.4s
#
# 2025-10-14 11:20:39 (254 KB/s) - ‘GSE115978_cell.annotations.csv.gz’ saved [101286/101286]

# %% [markdown]
# #Import libraries

# %%
import pandas as pd
import scanpy as sc
from scipy.sparse import csr_matrix
import scsurv.workflow as workflow
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #Import prepared files
# We can not make the actual bulk RNA-seq data from SKCM publicly available; users must download it themselves from the Genomic Data Commons (GDC) Data Portal(https://portal.gdc.cancer.gov/).
#
# In this tutorial, we use the highly variable genes calculated using the downloaded bulk RNA-seq data and the trained checkpoints of scSurv.

# %%
from importlib.resources import files, as_file
base = files("scsurv") / "data"
ref_genes = (base / "SKCM_ref_5000genes.txt").read_text(encoding="utf-8").splitlines()
with as_file(base / "SKCM_checkpoint.pt") as p:
    saved_pt = str(p)
with as_file(base / "SKCM_umap_coordinates.csv") as p:
    umap_df = pd.read_csv(p, index_col=0)

# %%
count_df = pd.read_csv('GSE115978_counts.csv.gz', index_col=0).T
annotation_df = pd.read_csv('GSE115978_cell.annotations.csv.gz', index_col=0)
sc_adata = sc.AnnData(X=csr_matrix(count_df.values), obs=annotation_df)
sc_adata.var_names = count_df.columns
sc_adata.obs = annotation_df
sc_adata.obs['cell.types'] = sc_adata.obs['cell.types'].replace('?', 'Undifined')
sc_adata.obsm['X_umap'] = umap_df[['UMAP1','UMAP2']].to_numpy()
sc_adata = sc_adata[:, ref_genes].copy()

# %% [markdown]
# #Run scSurv

# %%
bulk_adata = None
batch_key = 'samples'
exp_name = None
epoch = 10000

# %%
sc_adata, bulk_adata, _, _, vaesm_exp = workflow.run_scSurv(sc_adata, bulk_adata, exp_name, epoch, batch_key, saved_path = saved_pt)
# Out:
# make_sample_one_hot_mat
# torch.cuda.is_available() True
# /usr/local/lib/python3.12/dist-packages/torch/nn/init.py:582: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# vae_results
# all_x_correlation_gene 0.402 train_x_correlation_gene 0.420 val_x_correlation_gene 0.316 test_x_correlation_gene 0.318
# deconvolution_results
# Done post process

# %% [markdown]
# #Visualization

# %%
os.makedirs('fig', exist_ok=True)
fig, ax = plt.subplots(figsize=(8, 6))
sc.pl.umap(sc_adata, color='cell.types', ax=ax, show=False, colorbar_loc=None, frameon=False, legend_fontsize=11)
ax.set_title('', fontsize=20)
plt.savefig('fig/SKCM_umap_celltype.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9, 6))
sc.pl.umap(sc_adata, color='beta_z', ax=ax, show=False, colorbar_loc='right', frameon=False)
ax.set_title('Contribution to hazard', fontsize=20)
plt.savefig('fig/SKCM_umap_beta_z.png')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

sc.pl.umap(sc_adata, color='SPP1', ax=ax1, show=False, colorbar_loc='right', layer='xld', frameon=False, color_map='magma')
ax1.set_title('SPP1 expression', fontsize=20)

sc.pl.umap(sc_adata, color='TNFSF10', ax=ax2, show=False, colorbar_loc='right', layer='xld', frameon=False, color_map='magma')
ax2.set_title('TNFSF10 expression', fontsize=20)

plt.savefig('fig/SKCM_umap_SPP1_TNFSF10.png')
